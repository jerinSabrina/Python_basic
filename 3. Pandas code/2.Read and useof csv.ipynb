# %% [markdown]
# # Read csv from a directory path and  .csv

# %%
#import numpy as np
import pandas as pd

df = pd.read_csv('C:/Users/Sabrina/Desktop/q3 qnd q4.csv')
df = pd.read_csv('covid.csv')
df.head()
# Out:
#       tweet_id                                                text q1_label  \
# 0  1.241030e+18  For the average American the best way to tell ...       no
# 1  1.240470e+18                           this is fucking bullshit       no
# 2  1.240720e+18  Can y’all please just follow the government’s ...       no
# 3  1.241060e+18  No offense but the corono virus disappearing b...       no
# 4  1.241450e+18  This is the face of someone who just spent 9 h...       no
#
#   q2_label q3_label q4_label q5_label            q6_label            q7_label
# 0       no       no       no       no  no_joke_or_sarcasm  no_not_interesting
# 1       no       no       no       no      no_not_harmful  no_not_interesting
# 2       no       no       no       no      no_not_harmful  no_not_interesting
# 3       no       no       no       no      no_not_harmful  no_not_interesting
# 4       no       no       no       no      no_not_harmful  no_not_interesting

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 504 entries, 0 to 503
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0    tweet_id   504 non-null    float64
#  1   text        504 non-null    object
#  2   q1_label    504 non-null    object
#  3   q2_label    363 non-null    object
#  4   q3_label    504 non-null    object
#  5   q4_label    504 non-null    object
#  6   q5_label    363 non-null    object
#  7   q6_label    504 non-null    object
#  8   q7_label    504 non-null    object
# dtypes: float64(1), object(8)
# memory usage: 35.6+ KB

# %% [markdown]
# # Read file from IO

# %%
from io import StringIO,BytesIO

data = ('tweet_id,text,q1_label,q2_label,q3_label,q4_label,q5_label,q6_label,q7_label\n'
'24103,For the average American the best way to tell,no,no,no,no,no,no_joke_or_sarcasm,no_not_interesting\n'
'24047,this is fucking bullshit,no,no,no,no,no,no_not_harmful,no_not_interesting\n'
'24072,Can y’all please just follow the government’s instructionrecess,no,no,no,no,no,no_not_harmful,nointeresting')

df = pd.read_csv(StringIO(data))
df.head()
# Out:
#    tweet_id                                               text q1_label  \
# 0     24103      For the average American the best way to tell       no
# 1     24047                           this is fucking bullshit       no
# 2     24072  Can y’all please just follow the government’s ...       no
#
#   q2_label q3_label q4_label q5_label            q6_label            q7_label
# 0       no       no       no       no  no_joke_or_sarcasm  no_not_interesting
# 1       no       no       no       no      no_not_harmful  no_not_interesting
# 2       no       no       no       no      no_not_harmful       nointeresting

# %% [markdown]
# # read_csv(inbuild functions like usecols,dtype,index_col,escapechar)

# %%
df = pd.read_csv(StringIO(data),usecols=['text','q6_label','q7_label','tweet_id'])
df.head()
# Out:
#    tweet_id                                               text  \
# 0     24103      For the average American the best way to tell
# 1     24047                         this is \f\ucking bullshit
# 2     24072  Can y’all please just follow the government’s ...
#
#              q6_label            q7_label
# 0  no_joke_or_sarcasm  no_not_interesting
# 1      no_not_harmful  no_not_interesting
# 2      no_not_harmful       nointeresting

# %%
type(df['tweet_id'][1])
# Out:
# str

# %%
df = pd.read_csv(StringIO(data),dtype=str)
df.head()
# Out:
#   tweet_id                                               text q1_label  \
# 0    24103      For the average American the best way to tell       no
# 1    24047                         this is \f\ucking bullshit       no
# 2    24072  Can y’all please just follow the government’s ...       no
#
#   q2_label q3_label q4_label q5_label            q6_label            q7_label
# 0       no       no       no       no  no_joke_or_sarcasm  no_not_interesting
# 1       no       no       no       no      no_not_harmful  no_not_interesting
# 2       no       no       no       no      no_not_harmful       nointeresting

# %%
df= pd.read_csv(StringIO(data),index_col =0)
df
# Out:
#                                                        text q1_label q2_label  \
# tweet_id
# 24103         For the average American the best way to tell       no       no
# 24047                              this is fucking bullshit       no       no
# 24072     Can y’all please just follow the government’s ...       no       no
#
#          q3_label q4_label q5_label            q6_label            q7_label
# tweet_id
# 24103          no       no       no  no_joke_or_sarcasm  no_not_interesting
# 24047          no       no       no      no_not_harmful  no_not_interesting
# 24072          no       no       no      no_not_harmful       nointeresting

# %%
df= pd.read_csv(StringIO(data),index_col =1)
df
# Out:
#                                                     tweet_id q1_label  \
# text
# For the average American the best way to tell          24103       no
# this is \f\ucking bullshit                             24047       no
# Can y’all please just follow the government’s i...     24072       no
#
#                                                    q2_label q3_label q4_label  \
# text
# For the average American the best way to tell            no       no       no
# this is \f\ucking bullshit                               no       no       no
# Can y’all please just follow the government’s i...       no       no       no
#
#                                                    q5_label  \
# text
# For the average American the best way to tell            no
# this is \f\ucking bullshit                               no
# Can y’all please just follow the government’s i...       no
#
#                                                               q6_label  \
# text
# ...

# %%
df= pd.read_csv(StringIO(data),index_col =False)
df
# Out:
#    tweet_id                                               text q1_label  \
# 0     24103      For the average American the best way to tell       no
# 1     24047                         this is \f\ucking bullshit       no
# 2     24072  Can y’all please just follow the government’s ...       no
#
#   q2_label q3_label q4_label q5_label            q6_label            q7_label
# 0       no       no       no       no  no_joke_or_sarcasm  no_not_interesting
# 1       no       no       no       no      no_not_harmful  no_not_interesting
# 2       no       no       no       no      no_not_harmful       nointeresting

# %%
df= pd.read_csv(StringIO(data),escapechar='_')
df
# Out:
#    tweetid                                               text q1label q2label  \
# 0    24103      For the average American the best way to tell      no      no
# 1    24047                           this is fucking bullshit      no      no
# 2    24072  Can y’all please just follow the government’s ...      no      no
#
#   q3label q4label q5label          q6label           q7label
# 0      no      no      no  nojokeorsarcasm  nonotinteresting
# 1      no      no      no     nonotharmful  nonotinteresting
# 2      no      no      no     nonotharmful     nointeresting

# %% [markdown]
# # URL to CSV

# %%
df = pd.read_csv('https://download.bls.gov/pub/time.series/cu/cu.item',sep = '\t')
df
# Out:
#     item_code                                          item_name  \
# 0         AA0                               All items - old base
# 1        AA0R  Purchasing power of the consumer dollar - old ...
# 2         SA0                                          All items
# 3        SA0E                                             Energy
# 4       SA0L1                                All items less food
# ..        ...                                                ...
# 394   SS68023   Tax return preparation and other accounting fees
# 395   SSEA011                                  College textbooks
# 396  SSFV031A           Food at elementary and secondary schools
# 397   SSGE013                                 Infants' equipment
# 398   SSHJ031                                 Infants' furniture
#
#      display_level selectable  sort_sequence
# 0                0          T              2
# 1                0          T            399
# 2                0          T              1
# ...
